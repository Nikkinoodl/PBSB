# %% [markdown]
# ## Convert Archive Content in SQLLite
# Take each row in the existing PBSB database and convert it to a flat file. Discard unwanted fields. Change some parts of the image tags. We will use these files to dynamically generate website content using 11ty.

# %% [markdown]
# ### Imports

# %%
import sqlite3
import csv
import pandas as pd
import os
import json

# %% [markdown]
# ### Read Product Data from Database
# First, read the products from the PBSB database and write into a flat CSV output file.

# %%
# Connect to the SQLite database
conn = sqlite3.connect('C:\\Users\\simon\\Projects\\PBSB\\PBSB-Main.db')
cursor = conn.cursor()

# Query the data
# this is much simpler than the blog post extraction because everything we need is already in the table and
# each item is only associated with one category

cursor.execute("""SELECT 
    p.*
    FROM Product p
    ORDER BY p.CategoryName;""")

fileName = 'product.csv'

# Write to CSV
with open(fileName, 'w', newline='') as csv_file:
    writer = csv.writer(csv_file, quoting=csv.QUOTE_ALL, lineterminator='\n')
    # For this conversion, we skip the headers (can be useful during development)
    # writer.writerow([i[0] for i in cursor.description])
    # Write data
    writer.writerows(cursor.fetchall())

conn.close()

# %% [markdown]
# ### Process the CSV File
# Now switch to Pandas for easier processing of the data.

# %%
# Read the CSV file making sure we omit the header row
df = pd.read_csv(fileName, encoding='windows-1252', header=None)

# %%
df.head()
# Out:
#     0        1                                    2   \
# 0   91     Zeke     Zeke. Oil on linen 20x24in. 2010
# 1   97  Redford  Redford. Oil on linen 16x20in. 2008
# 2   99   Hannah   Hannah. Oil on linen 11x14in. 2010
# 3  100  Cracker  Cracker. Oil on linen 14x18in. 2009
# 4  102    Harry    Harry. Oil on linen 16x20in. 2011
#
#                                                   3                   4    5   \
# 0  Oil painting and portrait of golden retriever ...            Zeke.jpg  0.0
# 1            Oil painting of tibetan terrier Redford    RedfordCaire.jpg  0.0
# 2                  Oil painting of yellow lab Hannah      Hannah_new.jpg  0.0
# 3       Oil painting of jack russell terrier Cracker         Cracker.jpg  0.0
# 4               Oil portrait of basset mix dog Harry  Harry portrait.jpg  0.0
#
#     6     7    8   9    10   11  12
# 0  1.0  Dogs  1.0   1  NaN  NaN NaN
# 1  1.0  Dogs  1.0   1  NaN  NaN NaN
# 2  1.0  Dogs  1.0   1  NaN  NaN NaN
# 3  1.0  Dogs  1.0   1  NaN  NaN NaN
# 4  1.0  Dogs  1.0   1  NaN  NaN NaN

# %% [markdown]
# Delete unnecessary fields

# %%
df = df.drop(df.columns[[0, 5, 6, 8, 9, 12]], axis=1)
#df.reindex()
df.head()
# Out:
#         1                                    2   \
# 0     Zeke     Zeke. Oil on linen 20x24in. 2010
# 1  Redford  Redford. Oil on linen 16x20in. 2008
# 2   Hannah   Hannah. Oil on linen 11x14in. 2010
# 3  Cracker  Cracker. Oil on linen 14x18in. 2009
# 4    Harry    Harry. Oil on linen 16x20in. 2011
#
#                                                   3                   4   \
# 0  Oil painting and portrait of golden retriever ...            Zeke.jpg
# 1            Oil painting of tibetan terrier Redford    RedfordCaire.jpg
# 2                  Oil painting of yellow lab Hannah      Hannah_new.jpg
# 3       Oil painting of jack russell terrier Cracker         Cracker.jpg
# 4               Oil portrait of basset mix dog Harry  Harry portrait.jpg
#
#      7    10   11
# 0  Dogs  NaN  NaN
# 1  Dogs  NaN  NaN
# 2  Dogs  NaN  NaN
# 3  Dogs  NaN  NaN
# 4  Dogs  NaN  NaN

# %% [markdown]
# ### Wrangle the Data
#
# Convert image URL to match folder structure of new website

# %%
# Insert category name into URL
df.iloc[:, 3] = "/images/" + df.iloc[:, 4].astype(str) + "/" + df.iloc[:, 3].str.lstrip("/")

# %%
df.head()
# Out:
#         1                                    2   \
# 0     Zeke     Zeke. Oil on linen 20x24in. 2010
# 1  Redford  Redford. Oil on linen 16x20in. 2008
# 2   Hannah   Hannah. Oil on linen 11x14in. 2010
# 3  Cracker  Cracker. Oil on linen 14x18in. 2009
# 4    Harry    Harry. Oil on linen 16x20in. 2011
#
#                                                   3   \
# 0  Oil painting and portrait of golden retriever ...
# 1            Oil painting of tibetan terrier Redford
# 2                  Oil painting of yellow lab Hannah
# 3       Oil painting of jack russell terrier Cracker
# 4               Oil portrait of basset mix dog Harry
#
#                                 4     7    10   11
# 0            /images/Dogs/Zeke.jpg  Dogs  NaN  NaN
# 1    /images/Dogs/RedfordCaire.jpg  Dogs  NaN  NaN
# 2      /images/Dogs/Hannah_new.jpg  Dogs  NaN  NaN
# 3         /images/Dogs/Cracker.jpg  Dogs  NaN  NaN
# 4  /images/Dogs/Harry portrait.jpg  Dogs  NaN  NaN

# %% [markdown]
# ### Add Column Names

# %%
df.columns = ['Title', 'Description', 'Alt', 'Image', 'Category', 'Medium', 'Ground']

# Sort by 'Age' in descending order
# df = df.sort_values(by='Date', ascending=False)

# %% [markdown]
# ### Final Visual Inspection of the Data
# Last chance to visually inspect the data before handing it over to 11ty.

# %%
df.head()
# Out:
#      Title                          Description  \
# 0     Zeke     Zeke. Oil on linen 20x24in. 2010
# 1  Redford  Redford. Oil on linen 16x20in. 2008
# 2   Hannah   Hannah. Oil on linen 11x14in. 2010
# 3  Cracker  Cracker. Oil on linen 14x18in. 2009
# 4    Harry    Harry. Oil on linen 16x20in. 2011
#
#                                                  Alt  \
# 0  Oil painting and portrait of golden retriever ...
# 1            Oil painting of tibetan terrier Redford
# 2                  Oil painting of yellow lab Hannah
# 3       Oil painting of jack russell terrier Cracker
# 4               Oil portrait of basset mix dog Harry
#
#                              Image Category Medium Ground
# 0            /images/Dogs/Zeke.jpg     Dogs    NaN    NaN
# 1    /images/Dogs/RedfordCaire.jpg     Dogs    NaN    NaN
# 2      /images/Dogs/Hannah_new.jpg     Dogs    NaN    NaN
# 3         /images/Dogs/Cracker.jpg     Dogs    NaN    NaN
# 4  /images/Dogs/Harry portrait.jpg     Dogs    NaN    NaN

# %% [markdown]
# ### Write Out the Data to a Unix-type CSV file (has LF line endings, not CRLF)

# %% [markdown]
# Do this so we have an easily readable copy of the output on hand for reference. It is otherwise not used for the website.

# %%
# Write the cleaned-up data to the CSV file. Make sure there is a header row!

df.to_csv(fileName, index=False, header=True, lineterminator='\n')

# %% [markdown]
# ## Write Out Individual Blog Post Files

# %% [markdown]
# Create the individual files that will contain each blog post.

# %%
# Output directory
output_dir = "blog"
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# Data has already been cleaned and formatted so it can be written directly to an output file.

# %%
# Write each row to its own text file
for idx, row in df.iterrows():

    cats = str(row['Categories']).split(',')
    file_path = os.path.join(output_dir, str(row['Slug']) + ".liquid")

    try:
        with open(file_path, "w", encoding="utf-8") as f:
            f.write("--- \n")
            f.write("layout: post.njk" + "\n")
            f.write("title: \"" + str(row['Title']).replace('"', '\\"') + "\"\n")
            f.write("permalink: /blog/" + str(row['Slug']) + "/ \n")
            f.write("date: " + str(row['Date']) + "\n")
            f.write("shortdate: " + str(pd.to_datetime(row['Date']).strftime("%d %b %Y")) + "\n")
            f.write("image: " + str(row['Image']) + "\n")
            f.write("description: \"" + str(row['Description']).replace('"', '\\"') + "\"\n")
            f.write("categories:\n")
            for c in cats:
                f.write(f"  - {c.strip()}\n")
            f.write("tags: post" + "\n")
            f.write("--- \n")
            f.write("\n")
            f.write("\n")
            f.write(str(row['Content']))
    except OSError as e:
        print(f"Error writing file {file_path}: {e}")

print(f"{len(df)} files written to '{output_dir}'")
# Out:
# 389 files written to 'blog'
